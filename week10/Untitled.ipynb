# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data = df, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.histplot(data = df, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.countplot(data = df, x = 'tip')
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %%
sns.histplot(data=df, x = 'tip', bins=20, kde=True, hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.countplot(data = df, x = 'day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data = df, x = 'sex', hue = 'day', palette='pastel')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(data = df, x = 'day', y = 'tip', hue = 'sex', palette='pastel')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(data = df, x = 'day', y = 'tip', hue = 'sex', palette='pastel')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data = df, x = 'day', y = 'tip', palette='pastel')
# Out:
# C:\Users\francis\AppData\Local\Temp\ipykernel_16792\2611726469.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data = df, x = 'day', y = 'tip', palette='pastel')
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data = df, x = 'day', y = 'tip', palette='pastel', jitter = 0.2)
# Out:
# C:\Users\francis\AppData\Local\Temp\ipykernel_16792\912890419.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data = df, x = 'day', y = 'tip', palette='pastel', jitter = 0.2)
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data = df, x = 'day', y = 'tip', palette='pastel')
sns.boxplot(data = df, x = 'day', y = 'tip', hue = 'sex', palette='pastel')
# Out:
# C:\Users\francis\AppData\Local\Temp\ipykernel_16792\259310644.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data = df, x = 'day', y = 'tip', palette='pastel')
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(data = df, x = 'day', y = 'tip',hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(data = df, x = 'total_bill', y = 'tip',hue = 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data = df, x = 'total_bill', y = 'tip',hue = 'sex', marker='o')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df[ ['total_bill', 'tip', 'size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
a = df.select_dtypes(include=['float64','int64']).corr()
sns.heatmap(a, cmap='flare', lw=2)
# Out:
# <Axes: >

# %%
g=sns.jointplot(data= df, x='total_bill', y='tip', kind='reg')
g.fig.set_size_inches(3,3)

# %%
g=sns.JointGrid(data= df, x='total_bill', y='tip')
g.plot(sns.scatterplot, sns.histplot)
g.fig.set_size_inches(3,3)

# %%
sns.pairplot(df, hue='sex')

# %%
g = sns.PairGrid(df, hue='sex')
g.fig.set_size_inches(3,3)
g.map.(sns.histplot)
g.map_upper(sns.lineplot)
g.map_lower(sns.lineplot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 3
#       1 g = sns.PairGrid(df, hue='sex')
#       2 g.fig.set_size_inches(3,3)
# ----> 3 g.map.diagram(sns.histplot)
#       4 g.map_upper(sns.lineplot)
#       5 g.map_lower(sns.lineplot)
#
# AttributeError: 'function' object has no attribute 'diagram'

# %%
g = sns.FacetGrid(data = df, col ='day', row='sex')
g.map(sns.scatterplot, 'total_bill', 'tip')
