# %%
import pandas as pd
import numpy as np

# %%
#import dataset
df = pd.read_csv('retail_data.csv')
df
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 1            2174773.0      69749.0          Kelsey Hill
# 2            6679610.0      30192.0         Scott Jensen
# 3            7232460.0      62101.0        Joseph Miller
# 4            4983775.0      27901.0        Debra Coleman
# ...                ...          ...                  ...
# 302005       4246475.0      12104.0         Meagan Ellis
# 302006       1197603.0      69772.0          Mathew Beck
# 302007       7743242.0      28449.0           Daniel Lee
# 302008       9301950.0      45477.0       Patrick Wilson
# 302009       2882826.0      53626.0       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com  1.414787e+09             3959 Amanda Burgs
# 1               Mark36@gmail.com  6.852900e+09            82072 Dawn Centers
# ...

# %%
df.shape
# Out:
# (302010, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
# ...

# %%
df.describe()
# Out:
#        Transaction_ID    Customer_ID         Phone        Zipcode  \
# count    3.016770e+05  301702.000000  3.016480e+05  301670.000000
# mean     5.495823e+06   55006.553934  5.501464e+09   50298.951019
# std      2.595565e+06   26005.675200  2.596017e+09   28972.807134
# min      1.000007e+06   10000.000000  1.000049e+09     501.000000
# 25%      3.247930e+06   32469.250000  3.255061e+09   25425.000000
# 50%      5.499657e+06   55012.000000  5.505812e+09   50602.500000
# 75%      7.739509e+06   77511.000000  7.749860e+09   75252.000000
# max      9.999995e+06   99999.000000  9.999996e+09   99949.000000
#
#                  Age           Year  Total_Purchases         Amount  \
# count  301837.000000  301660.000000    301649.000000  301653.000000
# mean       35.481326    2023.165113         5.359729     255.163659
# std        15.021933       0.371283         2.868575     141.389640
# min        18.000000    2023.000000         1.000000      10.000219
# ...

# %%
#drop Transaction_ID, Customer_ID, Name, Email, Phone, Address  column
df.drop(columns=['Transaction_ID', 'Customer_ID', 'Name', 'Email', 'Phone', 'Address'], inplace=True)

# %%
df
# Out:
#               City            State  Zipcode    Country   Age  Gender  Income  \
# 0         Dortmund           Berlin  77985.0    Germany  21.0    Male     Low
# 1       Nottingham          England  99071.0         UK  19.0  Female     Low
# 2          Geelong  New South Wales  75929.0  Australia  48.0    Male     Low
# 3         Edmonton          Ontario  88420.0     Canada  56.0    Male    High
# 4          Bristol          England  48704.0         UK  22.0    Male     Low
# ...            ...              ...      ...        ...   ...     ...     ...
# 302005  Townsville  New South Wales   4567.0  Australia  31.0    Male  Medium
# 302006     Hanover           Berlin  16852.0    Germany  35.0  Female     Low
# 302007    Brighton          England  88038.0         UK  41.0    Male     Low
# 302008     Halifax          Ontario  67608.0     Canada  41.0    Male  Medium
# 302009      Tucson    West Virginia  25242.0        USA  28.0  Female     Low
#
# ...

# %%
#drop null value
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295916 entries, 0 to 302009
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   City              295916 non-null  object
#  1   State             295916 non-null  object
#  2   Zipcode           295916 non-null  float64
#  3   Country           295916 non-null  object
#  4   Age               295916 non-null  float64
#  5   Gender            295916 non-null  object
#  6   Income            295916 non-null  object
#  7   Customer_Segment  295916 non-null  object
#  8   Date              295916 non-null  object
#  9   Year              295916 non-null  float64
#  10  Month             295916 non-null  object
#  11  Time              295916 non-null  object
#  12  Total_Purchases   295916 non-null  float64
#  13  Amount            295916 non-null  float64
#  14  Total_Amount      295916 non-null  float64
#  15  Product_Category  295916 non-null  object
# ...

# %%
df.nunique()
# Out:
# City                   130
# State                   54
# Zipcode              93693
# Country                  5
# Age                     53
# Gender                   2
# Income                   3
# Customer_Segment         3
# Date                   366
# Year                     2
# Month                   12
# Time                 83496
# Total_Purchases         10
# Amount              293607
# Total_Amount        293610
# Product_Category         5
# Product_Brand           18
# Product_Type            33
# Feedback                 4
# Shipping_Method          3
# Payment_Method           4
# Order_Status             4
# Ratings                  5
# products               318
# dtype: int64

# %%
#visualize data
import matplotlib.pyplot as plt

# %%
x = df['Year']
y = df['Total_Amount']
plt.plot(x,y)
plt.show()

# %%
#
