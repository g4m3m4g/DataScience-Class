# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame( np.random.randint(1, 100, [5,4]),
                 index = list('abcde'), columns = list('WXYZ'))
df
# Out:
#     W   X   Y   Z
# a  58  27  99  53
# b  97  30  45  26
# c  71  63  84  92
# d   7  77  72  42
# e  25  42  91  95

# %%
df['I'] = [1,2,3,4,5]
df
# Out:
#     W   X   Y   Z  I
# a  58  27  99  53  1
# b  97  30  45  26  2
# c  71  63  84  92  3
# d   7  77  72  42  4
# e  25  42  91  95  5

# %%
df['J'] = np.zeros(len(df.index)) #สร้างตามความยาว ของ df
df
# Out:
#     W   X   Y   Z  I    J
# a  58  27  99  53  1  0.0
# b  97  30  45  26  2  0.0
# c  71  63  84  92  3  0.0
# d   7  77  72  42  4  0.0
# e  25  42  91  95  5  0.0

# %%
df['sum'] = df['W'] + df['X']
df
# Out:
#     W   X   Y   Z  I    J  sum
# a  23  14  70  26  1  0.0   37
# b  34  32  40  82  2  0.0   66
# c  81  98  69  88  3  0.0  179
# d  80  51  24  93  4  0.0  131
# e   9  30  87  47  5  0.0   39

# %%
df['J'] = [3,3,3,3,3] #แก้ค่าที่ col J
df
# Out:
#     W   X   Y   Z  I  J  sum
# a  23  14  70  26  1  3   37
# b  34  32  40  82  2  3   66
# c  81  98  69  88  3  3  179
# d  80  51  24  93  4  3  131
# e   9  30  87  47  5  3   39

# %%
def fn(x):
    if x > 50:
        return 'H'
    else:
        return 'L'

# %%
df['I'] = df['W'].apply(fn)
df
# Out:
#     W   X   Y   Z  I  J  sum
# a  23  14  70  26  L  3   37
# b  34  32  40  82  L  3   66
# c  81  98  69  88  H  3  179
# d  80  51  24  93  H  3  131
# e   9  30  87  47  L  3   39

# %%
df.drop('I', axis = 1) #axis = 1 ลบ col
# Out:
#     W   X   Y   Z  J  sum
# a  23  14  70  26  3   37
# b  34  32  40  82  3   66
# c  81  98  69  88  3  179
# d  80  51  24  93  3  131
# e   9  30  87  47  3   39

# %%
df.drop('I', axis = 1, inplace = True) #inplace คือลบไปที่ตัว df นั้นเลย แต่ข้างบนคือลบแบบจำลองไม่ได้ลบจริง
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.drop('I', axis = 1, inplace = True) #inplace คือลบไปที่ตัว df นั้นเลย แต่ข้างบนคือลบแบบจำลองไม่ได้ลบจริง
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df
# Out:
#     W   X   Y   Z  J  sum
# a  23  14  70  26  3   37
# b  34  32  40  82  3   66
# c  81  98  69  88  3  179
# d  80  51  24  93  3  131
# e   9  30  87  47  3   39

# %%
df.drop('J', axis = 1, inplace = True) 
df.drop('sum', axis = 1, inplace = True)
df
# Out:
#     W   X   Y   Z
# a  23  14  70  26
# b  34  32  40  82
# c  81  98  69  88
# d  80  51  24  93
# e   9  30  87  47

# %%
df.loc['b']
# Out:
# W    34
# X    32
# Y    40
# Z    82
# Name: b, dtype: int32

# %%
df.rename( index = {'a':'a1', 'b':'b1'}, inplace = True) #แก้ชื่อ index
df
# Out:
#      W   X   Y   Z
# a1  23  14  70  26
# b1  34  32  40  82
# c   81  98  69  88
# d   80  51  24  93
# e    9  30  87  47

# %%
df.rename( columns = {'W':'K'}, inplace = True ) #แก้ชื่อ col
df
# Out:
#      K   X   Y   Z
# a1  23  14  70  26
# b1  34  32  40  82
# c   81  98  69  88
# d   80  51  24  93
# e    9  30  87  47

# %%
df.reset_index(inplace = True) # เอา index มาตั้งเป็น col ใหม่ shift จากทางซ้าย
df
# Out:
#   index   K   X   Y   Z
# 0    a1  23  14  70  26
# 1    b1  34  32  40  82
# 2     c  81  98  69  88
# 3     d  80  51  24  93
# 4     e   9  30  87  47

# %%
df.set_index('index', inplace = True) #เอากลับไปแบบเดิม
df
# Out:
#         K   X   Y   Z
# index
# a1     23  14  70  26
# b1     34  32  40  82
# c      81  98  69  88
# d      80  51  24  93
# e       9  30  87  47

# %%
df1 = pd.DataFrame({
    'A': ['A0','A1','A2','A3'],
    'B': ['B0','B1','B2','B3'],
    'C': ['C0','C1','C2','C3'],
    'D': ['D0','D1','D2','D3']   
}, index = [0,1,2,3])

df2 = pd.DataFrame({
    'A': ['A4','A5','A6','A7'],
    'B': ['B4','B5','B6','B7'],
    'C': ['C4','C5','C6','C7'],
    'E': ['D4','D5','D6','D7']   
}, index = [2,3,4,5])

df3 = pd.DataFrame({
    'A': ['A8','A9','A10','A11'],
    'B': ['B8','B9','B10','B11'],
    'C': ['C8','C9','C10','C11'],
    'D': ['D8','D9','D10','D11']   
}, index = [6,7,8,9])

# %%
df = pd.concat([df1, df2], axis=0) #ต่อแบบแนวตั้ง
df
# Out:
#     A   B   C    D    E
# 0  A0  B0  C0   D0  NaN
# 1  A1  B1  C1   D1  NaN
# 2  A2  B2  C2   D2  NaN
# 3  A3  B3  C3   D3  NaN
# 2  A4  B4  C4  NaN   D4
# 3  A5  B5  C5  NaN   D5
# 4  A6  B6  C6  NaN   D6
# 5  A7  B7  C7  NaN   D7

# %%
df = pd.concat([df1, df2], axis = 1 ) #ต่อแบบแนวนอน
df
# Out:
#      A    B    C    D    A    B    C    E
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2   A4   B4   C4   D4
# 3   A3   B3   C3   D3   A5   B5   C5   D5
# 4  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 5  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
df1 = pd.DataFrame({
    'ID': ['A','B','C','D'],
    'Age': ['23','33','44','12'],
    'w': ['56','66','66','44'],   
}, index = [0,1,2,3])

df2 = pd.DataFrame({
    'ID': ['C','B','A','D'],
    'B': ['B4','B5','B6','B7'],
    'C': ['C4','C5','C6','C7'],
}, index = [2,3,4,5])

display(df1, df2)
# Out:
#   ID Age   w
# 0  A  23  56
# 1  B  33  66
# 2  C  44  66
# 3  D  12  44
#   ID   B   C
# 2  C  B4  C4
# 3  B  B5  C5
# 4  A  B6  C6
# 5  D  B7  C7

# %%
df1.reset_index(inplace=True)
df1.set_index('ID',inplace=True) #ทำ ID  เป็น index
df1.drop('index', axis = 1, inplace = True)
df1
# Out:
#    Age   w
# ID
# A   23  56
# B   33  66
# C   44  66
# D   12  44

# %%
df2.reset_index(inplace=True)
df2.set_index('ID',inplace=True)
df2.drop('index', axis = 1, inplace = True)
df2
# Out:
#      B   C
# ID
# C   B4  C4
# B   B5  C5
# A   B6  C6
# D   B7  C7

# %%
df = pd.concat([df1,df2], axis = 1)
df
# Out:
#    Age   w   B   C
# ID
# A   23  56  B6  C6
# B   33  66  B5  C5
# C   44  66  B4  C4
# D   12  44  B7  C7

# %%
df1 = pd.DataFrame({
    'ID': ['A',np.nan,np.nan,'D'],
    'Age': ['23',np.nan,'44',np.nan],
    'w': ['56','66',np.nan,'44'],   
}, index = [0,1,2,3])
df1
# Out:
#     ID  Age    w
# 0    A   23   56
# 1  NaN  NaN   66
# 2  NaN   44  NaN
# 3    D  NaN   44

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      2 non-null      object
#  1   Age     2 non-null      object
#  2   w       3 non-null      object
# dtypes: object(3)
# memory usage: 128.0+ bytes

# %%
df1[df1['ID'].isnull()]
# Out:
#     ID  Age    w
# 1  NaN  NaN   66
# 2  NaN   44  NaN

# %%
(df1['ID'].isnull()).sum()
# Out:
# np.int64(2)

# %%
df1['ID'].notnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: ID, dtype: bool

# %%
df1[df1['ID'].notnull()]
# Out:
#   ID  Age   w
# 0  A   23  56
# 3  D  NaN  44

# %%
df1.dropna()
# Out:
#   ID Age   w
# 0  A  23  56

# %%
df1.dropna( thresh = len(df1.columns)-1 ) #ต้องมีข้อมูลอย่างต่า 2 ตัว
# Out:
#   ID  Age   w
# 0  A   23  56
# 3  D  NaN  44

# %%
df1.dropna(axis = 1) #ลบใน col
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df1.fillna(value = 1 ) #เติมค่า nan ให้เป็น 1
# Out:
#   ID Age   w
# 0  A  23  56
# 1  1   1  66
# 2  1  44   1
# 3  D   1  44

# %%
df1['ID'].fillna(value = 'X')
# Out:
# 0    A
# 1    X
# 2    X
# 3    D
# Name: ID, dtype: object

# %%
def fn(x):
    return int(x)

df1['Age'] = df1['Age'].apply(fn)
# Out:
#     ID  Age    w
# 0    A   23   56
# 1  NaN  NaN   66
# 2  NaN   44  NaN
# 3    D  NaN   44

# %%
def fn(x):
    if x is np.nan:
        return np.nan
    else:
        return int(x)

df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df1['Age'].fillna(value = df1['Age'].mean(), inplace = True)
#       2 df1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df1.fillna(value = df1['Age'].mean(), inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...
